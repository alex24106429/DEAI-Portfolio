# %% [markdown]
# Maak een eigen implementatie van een ’Singly linked list’. Er zijn meerdere implementaties denkbaar, maar we
# adviseren om de list als abstracte class te implementeren met twee concrete subclasses. Een voor lege en een voor
# niet-lege lijsten.

# %%
class LinkedList:
    pass

class LinkedListEmpty(LinkedList):
    def __init__(self):
        pass

class LinkedListPopulated(LinkedList):
    def __init__(self, head, tail):
        self.head = head
        self.tail = tail

# %% [markdown]
# Schrijf een (recursieve) methode ’toString’, die een lijst omzet naar een string waarin de inhoud wordt opgesomt
# gescheiden door een spatie. (Een overtollige spatie aan het einde is niet erg.) Een lijst met elementen ’4’ en ’7’
# bijvoorbeeld, zou omgezet worden naar ”4 7 ”. Schrijf voorbeeldcode met lijsten van 0, 1 en 2 elementen.

# %%
def toString(self):
    return ""

LinkedListEmpty.toString = toString


def toString(self):
    return str(self.head) + " " + self.tail.toString()


LinkedListPopulated.toString = toString

lijst_0 = LinkedListEmpty()
lijst_1 = LinkedListPopulated(4, LinkedListEmpty())
lijst_2 = LinkedListPopulated(4, LinkedListPopulated(7, LinkedListEmpty()))

print("Opdracht 2:")
print("0 elementen:", lijst_0.toString())
print("1 element:  ", lijst_1.toString())
print("2 elementen:", lijst_2.toString())
# Out:
# Opdracht 2:
# 0 elementen:
# 1 element:   4
# 2 elementen: 4 7

# %% [markdown]
# Schrijf een (recursieve) methode ’addFirst(value), die een nieuwe lijst retourneert met de gegeven waarde vooraan
# en daarna alle elementen uit de oorspronkelijke lijst. Een aanroep van ’addFirst(5)’ op een lijst met elementen ’4’ en
# ’7’ bijvoorbeeld levert een nieuwe lijst op met elementen ’5’, ’4’ en ’7’. Schrijf voorbeeldcode die aannemelijk maakt
# dat de methode correct werkt.

# %%
def addFirst(self, value):
    return LinkedListPopulated(value, self)


LinkedListEmpty.addFirst = addFirst
LinkedListPopulated.addFirst = addFirst

print("2 elementen:", lijst_2.toString())

nieuwe_lijst_2 = lijst_2.addFirst(5)

print("3 elementen:", nieuwe_lijst_2.toString())
# Out:
# 2 elementen: 4 7
# 3 elementen: 5 4 7

# %% [markdown]
# Schrijf een (recursieve) methode ’remove(value), die een nieuwe lijst retourneert met alle elementen uit de oor-
# spronkelijke lijst, behalve het eerste voorkomen van de gegeven waarde. Een aanroep van ’remove(4)’ op een lijst
# met elementen ’5’, ’4’, ’7’ en ’4’ bijvoorbeeld levert een nieuwe lijst op met elementen ’5’, ’7’ en ’4’. Een aanroep
# van ’remove(4)’ op deze laatste lijst levert een nieuwe lijst op met elementen ’5’ en ’7’. Schrijf voorbeeldcode die
# aannemelijk maakt dat de methode correct werkt.

# %%
def remove(self, value):
    return self

LinkedListEmpty.remove = remove

def remove(self, value):
    if self.head == value:
        return self.tail
    else:
        return LinkedListPopulated(self.head, self.tail.remove(value));

LinkedListPopulated.remove = remove

lijst = LinkedListEmpty().addFirst(4).addFirst(7).addFirst(4).addFirst(5)
print("\nOpdracht 4:")
print("Origineel:        ", lijst.toString())  # 5 4 7 4
lijst_zonder_4 = lijst.remove(4)
print("Na eerste remove: ", lijst_zonder_4.toString())  # 5 7 4
lijst_zonder_nog_een_4 = lijst_zonder_4.remove(4)
print("Na tweede remove: ", lijst_zonder_nog_een_4.toString())  # 5 7
# Out:
# Opdracht 4:
# Origineel:         5 4 7 4
# Na eerste remove:  5 7 4
# Na tweede remove:  5 7

# %% [markdown]
# We zijn een eind opgeschoten! Het eenvoudige sorteeralgoritme dat we gaan schrijven werkt (ongeveer) als volgt.
# Vind het kleinste element in de oorspronkelijke lijst en verwijder dit. Voeg het toe aan een nieuwe lijst en herhaal
# alle stappen tot de oorspronkelijke lijst leeg is. Omdat alle elementen in volgorde van klein naar groot aan de nieuwe
# lijst zijn toegevoegd is de nieuwe lijst gesorteerd.
# Er is nog een kleine hulpmethode nodig. Schrijf een (recursieve) methode ’smallest()’ die de kleinste waarde van
# een lijst retourneert. Een aanroep van ’smallest()’ op een lijst met elementen ’5’, ’4’ en ’7’ bijvoorbeeld geeft ’4’ als antwoord. Schrijf voorbeeldcode die aannemelijk maakt dat de methode correct werkt.

# %%
def smallest(self):
    raise ValueError("Empty list has no smallest element")

LinkedListEmpty.smallest = smallest

def smallest(self):
    if isinstance(self.tail, LinkedListEmpty):
        return self.head
    else:
        tail_smallest = self.tail.smallest()
        return self.head if self.head < tail_smallest else tail_smallest

LinkedListPopulated.smallest = smallest

lijst1 = LinkedListEmpty().addFirst(4).addFirst(7).addFirst(5)

print("Lijst 1:", lijst1.toString())
print("Kleinste:", lijst1.smallest())
# Out:
# Lijst 1: 5 7 4
# Kleinste: 4

# %% [markdown]
# Alle ingredienten zijn aanwezig voor het eenvoudige sorteeralgoritme! Schrijf een (recursieve) methode ’sortSimple(),
# die een nieuwe lijst retourneert met alle elementen uit de oorspronkelijke lijst gesorteerd van klein naar groot. Een
# aanroep van ’sortSimple()’ op een lijst met elementen ’5’, ’4’, ’7’ en ’4’ bijvoorbeeld levert een nieuwe lijst op met
# elementen ’4’, ’4’, ’5’ en ’7’. Schrijf voorbeeldcode die aannemelijk maakt dat de methode correct werkt.
# Mocht een recursieve methode te lastig zijn mag een niet-recursieve methode ook. Het kan dan handig zijn om
# gebruik te maken van een hulpmethode ’largest()’ in plaats van ’smallest()’.

# %%
def sortSimple(self):
    return self

LinkedListEmpty.sortSimple = sortSimple

def sortSimple(self):
    kleinste = self.smallest()
    rest = self.remove(kleinste)
    return rest.sortSimple().addFirst(kleinste)

LinkedListPopulated.sortSimple = sortSimple

lijst_sort = LinkedListEmpty().addFirst(4).addFirst(7).addFirst(4).addFirst(5)
print("\nOpdracht 6:")
print("Ongesorteerd:", lijst_sort.toString())
gesorteerd = lijst_sort.sortSimple()
print("Gesorteerd:  ", gesorteerd.toString())
# Out:
# Opdracht 6:
# Ongesorteerd: 5 4 7 4
# Gesorteerd:   4 4 5 7

# %% [markdown]
# Download de bestanden ’Read.py’ en ’kentekens1000.txt’ van Brightspace. Gebruik de code in ’Read.py’ om het
# bestand met kentekens in te lezen in een lijst (of schrijf hiervoor je eigen code). Gebruik de ’sortSimple()’ methode
# om ze te sorteren en ’toString()’ om ze uit te printen. Zijn ze netjes gesorteerd?

# %%
import csv
import sys

sys.setrecursionlimit(20000000)


kentekens = LinkedListEmpty()

with open("kentekens1000.csv") as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        kentekens = kentekens.addFirst(row[0])

kentekenssorted = kentekens.sortSimple()
print("\nOpdracht 7:")
print("kentekenssorted:", kentekenssorted.toString())
# Out:
# Opdracht 7:
# ...

# %% [markdown]
# Schrijf een (recursieve) methode ’uniq()’die, indien aangeroepen op een gesorteerde lijst, retourneert hoeveel unieke
# elementen de lijst bevat. Een aanroep van ’uniq()’ op een lijst met elementen ’4’, ’4’, ’5’ en ’7’ bijvoorbeeld geeft ’3’
# als antwoord. Schrijf voorbeeldcode die aannemelijk maakt dat de methode correct werkt.

# %%
def uniq(self):
    return 0


LinkedListEmpty.uniq = uniq


def uniq(self):
    if isinstance(self.tail, LinkedListEmpty):
        return 1
    if self.head == self.tail.head:
        return self.tail.uniq()
    else:
        return 1 + self.tail.uniq()


LinkedListPopulated.uniq = uniq

print("\nOpdracht 8 (Uniq):")
print("Lijst: ", gesorteerd.toString())
print("Aantal uniek: ", gesorteerd.uniq())
# Out:
# Opdracht 8 (Uniq):
# Lijst:  4 4 5 7
# Aantal uniek:  3

# %% [markdown]
# Gebruik de methode ’uniq()’ om te bepalen hoeveel unieke kentekens het bestand ’kentekens1000.txt’ bevat. Hoeveel
# zijn dit er?

# %%
kentekenssorteduniq = kentekenssorted.uniq()
print("Aantal unieke kentekens: ", kentekenssorteduniq)
# Out:
# Aantal unieke kentekens:  998

# %% [markdown]
# Ga naar de Open Data webpagina van de overheid2 en download (onder tabblad ’Databronnen’) het ’Text/Csv’
# bestand met de kentekenregistraties in Nederland. Verwijder de eerste regel uit het bestand. Gebruik de code uit de
# vorige opdracht om te bepalen hoeveel unieke kentekens dit bestand bevat. Lukt dit? Geef een verklaring waarin je
# laat zien ook de stof uit de hoorcolleges te beheersen.

# %%
sys.setrecursionlimit(20000000)


kentekensOverheid = LinkedListEmpty()

with open("Databronnen.csv") as f:
    reader = csv.reader(f, delimiter=',')
    for row in reader:
        kentekensOverheid = kentekensOverheid.addFirst(row[0])

kentekenssortedOverheid = kentekensOverheid.sortSimple()
kentekenssortedOverheiduniq = kentekenssortedOverheid.uniq()
print("Aantal unieke kentekens in overheid: ", kentekenssortedOverheiduniq)
